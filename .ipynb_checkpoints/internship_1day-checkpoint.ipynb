# %% [markdown]
# <h1>カルフォルニア_住宅価格 回帰分析</h1>
# <br>参考:</br>
# <br>【Python】scikit-learnのcalifornia housing datasetを使って回帰分析をしてみる</br>
# <br> https://zenn.dev/omochimaru/articles/9b289f4a9455b7 </br>
#
# <br>scikit-learn カリフォルニア住宅価格データの前処理に関する見解</br>
# <br> https://qiita.com/kakiuchis/items/fb25c54af77df6e394ca </br>

# %%
#必要なライブラリをインポート

from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import seaborn as sns

# %% [markdown]
# <h2>データ概要</h2>

# %% [markdown]
# <h3>housing.data</h3>
# <br>Medlnc	    :世帯所得の中央値</br>
# <br>HouseAge	:住宅の築年数</br>
# <br>AveRooms	:住宅の部屋数の平均</br>
# <br>AveBedrms	:住宅の寝室数の平均</br>
# <br>Poplation	:居住人数の合計</br>
# <br>AveOcuup	:世帯人数の平均</br>
# <br>Latitude	:各地区における代表地区の緯度</br>
# <br>HousePrices	:各地区における代表地区の経度</br>
#
# <h3>housing.target</h3>
#
# <br>MedHouseVal :カリフォルニア住宅価格<br>

# %% [markdown]
# <h2>データの中身確認</h2>

# %%
housing = fetch_california_housing(as_frame=True)

# %%
housing.data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
housing.target
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
#housing.data と housing.targetの結合
housing_all = pd.concat([housing.data, housing.target],axis=1)

# %%
#要約統計量出力
housing_all.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.tight_layout()
housing_all.hist(bins=20, ax=ax)
# Out:
# C:\Users\mitakama\AppData\Local\Temp\ipykernel_40772\116469585.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   housing_all.hist(bins=20, ax=ax)
# array([[<Axes: title={'center': 'MedInc'}>,
#         <Axes: title={'center': 'HouseAge'}>,
#         <Axes: title={'center': 'AveRooms'}>],
#        [<Axes: title={'center': 'AveBedrms'}>,
#         <Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'AveOccup'}>],
#        [<Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Longitude'}>,
#         <Axes: title={'center': 'MedHouseVal'}>]], dtype=object)

# %%
#世帯数
sns.stripplot(data = housing_all['AveOccup'])
# Out:
# <Axes: ylabel='AveOccup'>

# %%
housing_all.query("AveOccup > 200")[["Latitude","Longitude"]]
# Out:
#        Latitude  Longitude
# 3364      40.41    -120.51
# 13034     38.69    -121.15
# 16669     35.32    -120.70
# 19006     38.32    -121.98

# %%
sns.boxplot(x=housing_all["Population"])
# Out:
# <Axes: xlabel='Population'>

# %%
#外れ値を除いたAveBedrmsの箱ひげ図

df = housing_all.copy()

df_bedrms = pd.DataFrame(df["AveBedrms"])
indexNames1 = df_bedrms[df_bedrms["AveBedrms"] >=2].index
#indexNames2 = df_bedrms[df_bedrms["AveBedrms"] <=0.80].index

df_bedrms.drop(indexNames1, inplace=True)
#df_bedrms.drop(indexNames2, inplace=True)
sns.boxplot(x=df_bedrms["AveBedrms"])
# Out:
# <Axes: xlabel='AveBedrms'>

# %%
sns.boxplot(x=housing_all["Population"])
# Out:
# <Axes: xlabel='Population'>

# %%
df = housing_all.copy()

df = pd.DataFrame(df["Population"])
indexNames1 = df[df["Population"] >=3000].index
#indexNames2 = df_bedrms[df_bedrms["AveBedrms"] <=0.80].index

df.drop(indexNames1, inplace=True)
#df_bedrms.drop(indexNames2, inplace=True)
sns.boxplot(x=df["Population"])
# Out:
# <Axes: xlabel='Population'>

# %%
#散布図
#sns.pairplot(housing_all)

# %%
#相対係数のヒートマップ
sns.heatmap(housing_all.corr(), annot=True, fmt='.2f',square=True)
# Out:
# <Axes: >

# %%
housing_all["Population"].max()
# Out:
# 35682.0

# %%
#緯度経度と人口の関係
fig, ax = plt.subplots(1,1,figsize=(5,5), dpi=100)

cmap = cm.Blues
norm = mpl.colors.Normalize(vmin=housing_all["Population"].min(), vmax=housing_all["Population"].max())

ax.set_xlabel("latitude")
ax.set_ylabel("longitude")

ax.scatter(housing.data["Latitude"], housing.data["Longitude"],s=10,
          color = mpl.cm.ScalarMappable(norm=norm, cmap=cmap).to_rgba(housing.data["Population"]))

# %% [markdown]
# <h2>単回帰分析</h2>

# %%
#説明変数と目的変数の指定

data = housing_all.copy()

exp_var = 'MedInc' # 説明変数
tar_var = 'MedHouseVal' # 目的変数

# %%
# 散布図を表示
plt.figure(figsize=(12, 9))
plt.scatter(data[exp_var], data[tar_var])
plt.xlabel(exp_var)
plt.ylabel(tar_var)
#plt.savefig('california_housing_scatter.png')
# Out:
# Text(0, 0.5, 'MedHouseVal')

# %%
 data["MedHouseVal"].max()
# Out:
# 5.00001

# %%
#追加分
# 外れ値を除去

#MedHouseValが最大値に密集 --> 5以上の値全てがまれている可能性

val_max = data["MedHouseVal"].max()

indexNames1 = data[data["MedHouseVal"] == val_max].index
#indexNames2 = df_bedrms[df_bedrms["AveBedrms"] <=0.80].index

data.drop(indexNames1, inplace=True)

plt.figure(figsize=(12, 9))
plt.scatter(data[exp_var], data[tar_var])
plt.xlabel(exp_var)
plt.ylabel(tar_var)
# Out:
# Text(0, 0.5, 'MedHouseVal')

# %%
# 記述統計量を確認
data[["MedInc","MedHouseVal"]].describe()
# Out:
#              MedInc   MedHouseVal
# count  19675.000000  19675.000000
# mean       3.676717      1.924779
# std        1.570272      0.977115
# min        0.499900      0.149990
# 25%        2.526800      1.166000
# 50%        3.450000      1.738000
# 75%        4.582600      2.482000
# max       15.000100      5.000000

# %%
# 説明変数と目的変数にデータを分割
X = data[[exp_var]]
print(data.shape)
display(X.head())
y = data[[tar_var]]
print(y.shape)
display(y.head())
# Out:
# (19675, 9)
#    MedInc
# 0  8.3252
# 1  8.3014
# 2  7.2574
# 3  5.6431
# 4  3.8462
# (19675, 1)
#    MedHouseVal
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422

# %%
# 学習
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# 精度の確認
print('回帰直線の切片', model.intercept_[0])
print('回帰係数', model.coef_[0][0])
print('決定係数', model.score(X, y))
print('回帰直線', 'y = ', model.coef_[0][0], 'x + ', model.intercept_[0])
# Out:
# 回帰直線の切片 0.4545699678231845
# 回帰係数 0.39987012062314825
# 決定係数 0.4129486198582023
# 回帰直線 y =  0.39987012062314825 x +  0.4545699678231845

# %%
# 回帰直線と散布図を表示
plt.figure(figsize=(12, 9))
plt.scatter(X, y)
plt.plot(X, model.predict(X), color='red')
plt.xlabel(exp_var)
plt.ylabel(tar_var)
plt.title('california_housing_regression')
#plt.savefig('california_housing_regression.png')
# Out:
# Text(0.5, 1.0, 'california_housing_regression')

# %% [markdown]
# <h2>重回帰分析</h2>

# %%
data = housing_all.copy()

# %%
# 説明変数
#exp_vars = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
exp_vars = ['MedInc', 'HouseAge', 'AveRooms','Population', ]
# 目的変数
tar_var = "MedHouseVal"

# %%
#欠陥値の有無確認
housing_all.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
# 住宅価格の外れ値を除去 
exp_var = 'MedInc'
tar_var = 'MedHouseVal' 

val_max = data["MedHouseVal"].max()
indexNames = data[data["MedHouseVal"] == val_max].index
data.drop(indexNames, inplace=True)

plt.figure(figsize=(12, 9))
plt.scatter(data[exp_var], data[tar_var])
plt.xlabel(exp_var)
plt.ylabel(tar_var)
# Out:
# Text(0, 0.5, 'MedHouseVal')

# %%
exp_var = 'HouseAge'
tar_var = 'MedHouseVal' 

plt.figure(figsize=(12, 9))
plt.scatter(data[exp_var], data[tar_var])
plt.xlabel(exp_var)
plt.ylabel(tar_var)
# Out:
# Text(0, 0.5, 'MedHouseVal')

# %%
#築年数の外れ値を除去
age_max = data["HouseAge"].max()
indexNames = data[data["HouseAge"] == age_max].index
data.drop(indexNames, inplace=True)

plt.figure(figsize=(12, 9))
plt.scatter(data[exp_var], data[tar_var])
plt.xlabel(exp_var)
plt.ylabel(tar_var)
# Out:
# Text(0, 0.5, 'MedHouseVal')

# %%
# 説明変数と目的変数にデータを分割
X = data[exp_vars]
print(data.shape)
display(X.head())
y = data[[tar_var]]
print(y.shape)
display(y.head())
y = data[[tar_var]]
print(y.shape)
display(y.head())
# 訓練データとテストデータに分割
# 分割のためのモジュールをインポート
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, random_state=0)
print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', len(X_test))
print('y_test', len(y_test))
# Out:
# (18572, 9)
#     MedInc  HouseAge  AveRooms  Population
# 0   8.3252      41.0  6.984127       322.0
# 1   8.3014      21.0  6.238137      2401.0
# 8   2.0804      42.0  4.294118      1206.0
# 15  2.1250      50.0  4.242424       697.0
# 18  1.9911      50.0  5.343675       990.0
# (18572, 1)
#     MedHouseVal
# 0         4.526
# 1         3.585
# 8         2.267
# 15        1.400
# 18        1.587
# (18572, 1)
#     MedHouseVal
# 0         4.526
# 1         3.585
# 8         2.267
# 15        1.400
# 18        1.587
# X_train (14857, 4)
# y_train (14857, 1)
# X_test 3715
# y_test 3715

# %%
#  X_trainを標準化する
# 標準化ライブラリをインポート
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
print('X_train_scaled', X_train_scaled.shape)
X_train_scaled = pd.DataFrame(X_train_scaled, columns = exp_vars)
display(X_train_scaled.head())
# Out:
# X_train_scaled (14857, 4)
#      MedInc  HouseAge  AveRooms  Population
# 0  2.664736 -1.048086  0.301893   -0.557578
# 1 -0.018423  0.438078  0.706949   -0.826081
# 2 -0.293513 -1.310351  0.309433   -0.613160
# 3 -1.430257  1.661978 -0.063018   -0.853445
# 4 -0.283954  1.312293 -0.846676   -0.066746

# %%
# 学習
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
# 予測値を計算
y_pred = model.predict(X_train_scaled)
y_pred[:10]

# 偏回帰係数を計算 
for xi, wi in zip(exp_vars, model.coef_[0]):
    print('{0:7s}: {1:6.3f}'.format(xi, wi))
# Out:
# MedInc :  0.686
# HouseAge:  0.148
# AveRooms: -0.079
# Population:  0.030

# %%
# 決定係数
print('決定係数:{:.3f}'.format(model.score(X_train_scaled, y_train)))

from sklearn.metrics import mean_squared_error

# 訓練データに対する Mean Squared Error (MSE)
mse_train = mean_squared_error(y_train, y_pred)
print("訓練データに対するMSE: {:.3f}".format(mse_train))

# テストデータに対する MSE
X_test_scaled = scaler.transform(X_test) # テストデータを訓練データから得られた平均と標準偏差で標準化
y_test_pred = model.predict(X_test_scaled) # テストデータに対して予測する
mse_test = mean_squared_error(y_test, y_test_pred)
print("テストデータに対するMSE: {:.3f}".format(mse_test))
# Out:
# 決定係数:0.466
# 訓練データに対するMSE: 0.489
# テストデータに対するMSE: 0.484
# C:\Users\mitakama\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
## Ridge回帰

from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1.0)
ridge.fit(X_train_scaled, y_train)
ridge_y_pred = ridge.predict(X_train_scaled)

# %%
# 偏回帰係数の確認
ridge_w = pd.DataFrame(ridge.coef_.T, index=exp_vars, columns=['Ridge'])
for xi, wi in zip(exp_vars, ridge.coef_[0]):
    print('{0:7s}: {1:6.3f}'.format(xi, wi))
print('L2ノルム: {:.3f}'.format(np.linalg.norm(ridge.coef_)))
# Out:
# MedInc :  0.686
# HouseAge:  0.148
# AveRooms: -0.079
# Population:  0.030
# L2ノルム: 0.707

# %%
# 訓練データに対する Mean Squared Error (MSE)
ridge_mse_train = mean_squared_error(y_train, ridge_y_pred)
print("訓練データに対するMSE: {:.3f}".format(ridge_mse_train))

# テストデータに対する MSE
ridge_y_test_pred = ridge.predict(X_test_scaled) # テストデータに対して予測する
ridge_mse_test = mean_squared_error(y_test, ridge_y_test_pred)
print("テストデータに対するMSE: {:.3f}".format(ridge_mse_test))

# 決定係数
print('決定係数:{:.3f}'.format(ridge.score(X_train_scaled, y_train)))
# Out:
# 訓練データに対するMSE: 0.489
# テストデータに対するMSE: 0.484
# 決定係数:0.466
# C:\Users\mitakama\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(

# %%
data = {'訓練データMSE':[mse_train, ridge_mse_train], 
        'テストデータMSE':[mse_test, ridge_mse_test], 
        '決定係数':[model.score(X_test_scaled, y_test), ridge.score(X_test_scaled, y_test)]}
df_mse = pd.DataFrame(data=data, index=['重回帰', 'Ridge回帰'])
df_mse
# Out:
# C:\Users\mitakama\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\mitakama\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
#          訓練データMSE  テストデータMSE      決定係数
# 重回帰      0.489442   0.484358  0.473589
# Ridge回帰  0.489442   0.484358  0.473589

# %% [markdown]
# <h2>タイタニック</h2>

# %%
#データの読み込み
df = pd.read_csv('./input/titanic3.csv')

# %%
#ラベルエンコーディング
df_copy =df.copy()

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder() #ラベルエンコーダのインスタンスを作成

df_copy['sex'] = le.fit_transform(df_copy['sex']) #エンコーディング
df_copy['embarked'] = le.fit_transform(df_copy['embarked'])
df_copy.head()

df_copy['embarked']
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    2
# Name: embarked, Length: 1309, dtype: int32

# %%
#欠損値確認
df_copy.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        0
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
#欠損値保管
df_copy['age'] = df_copy['age'].fillna(df_copy['age'].mean()) #欠損値にageの平均値で補完
df_copy['fare'] = df_copy['fare'].fillna(df_copy['fare'].mean()) #欠損値にfareの平均値で補完
print(df_copy.isnull().sum())
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin        1014
# embarked        0
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
#不要列の削除
df_copy = df_copy.drop(['name', 'ticket', 'cabin', 'boat', 'body', 'home.dest'],axis=1)
df_copy
# Out:
#       pclass  survived  sex        age  sibsp  parch      fare  embarked
# 0          1         1    0  29.000000      0      0  211.3375         2
# 1          1         1    1   0.920000      1      2  151.5500         2
# 2          1         0    0   2.000000      1      2  151.5500         2
# 3          1         0    1  30.000000      1      2  151.5500         2
# 4          1         0    0  25.000000      1      2  151.5500         2
# ...      ...       ...  ...        ...    ...    ...       ...       ...
# 1304       3         0    0  14.500000      1      0   14.4542         0
# 1305       3         0    0  29.881138      1      0   14.4542         0
# 1306       3         0    1  26.500000      0      0    7.2250         0
# 1307       3         0    1  27.000000      0      0    7.2250         0
# 1308       3         0    1  29.000000      0      0    7.8750         2
#
# [1309 rows x 8 columns]

# %%
# ndarray形式への変換

features = df_copy[['pclass','age','sex','fare','embarked']].values
#features = df_copy[['age','sex','fare']].values
target = df_copy['survived'].values

# %%
# 学習データとテストデータに分割

from sklearn.model_selection import train_test_split

(features , test_X , target , test_y) = train_test_split(features, target , test_size = 0.3 , random_state = 0)

# %%
#学習の実行

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100,random_state=0) # ランダムフォレストのインスタンスを作成

model.fit(features,target) # 学習の実行
# Out:
# RandomForestClassifier(random_state=0)

# %%
# 予測の実行
pred = model.predict(test_X)

# %%
# 【98】予測精度の確認
from sklearn.metrics import accuracy_score

accuracy_score(pred,test_y)
# Out:
# 0.7888040712468194

# %%
# 重要度の確認
# 学習における各列(特徴量)の
# 重要度を表示

importance = model.feature_importances_ 

print('Feature Importances:')
for i, feat in enumerate(['pclass','age','sex','fare','embarked']):
#for i, feat in enumerate(['age','sex','fare']):
    print('\t{0:20s} : {1:>.5f}'.format(feat, importance[i]))
# Out:
# Feature Importances:
# 	pclass               : 0.08893
# 	age                  : 0.28727
# 	sex                  : 0.27940
# 	fare                 : 0.31417
# 	embarked             : 0.03023

# %%
df_pred = pd.DataFrame(pred)
df_pred.to_csv('./output/submission.csv',header=None)
